# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.base import BaseEstimator as est
import warnings
import time
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

start_time = time.time()
warnings.filterwarnings('ignore')

print(__doc__)

# Loading the Digits dataset
digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(digits.images)
X = digits.images.reshape((n_samples, -1))
y = digits.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = {
'bootstrap': [True, False], 
'max_depth': [1,2,3],
'n_estimators': [10, 50, 100, 200, 500],
'max_features': [1,2,3,4,5,6,7,8]}

scores = ['f1']

print('\n' + 'parameters:' + "\n" + str(est.get_params(RandomForestClassifier)) + '\n')
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        RandomForestClassifier(), tuned_parameters, scoring='%s_macro' % score
    )
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
print("Time Consumed: " + str(time.time()-start_time))
# Out:
# Automatically created module for IPython interactive environment
#
# parameters:
# {'bootstrap': None, 'ccp_alpha': None, 'class_weight': None, 'criterion': None, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': None, 'min_impurity_split': None, 'min_samples_leaf': None, 'min_samples_split': None, 'min_weight_fraction_leaf': None, 'n_estimators': None, 'n_jobs': None, 'oob_score': None, 'random_state': None, 'verbose': None, 'warm_start': None}
#
# # Tuning hyper-parameters for f1
#
# Best parameters set found on development set:
#
# {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'n_estimators': 500}
#
# Grid scores on development set:
#
# 0.421 (+/-0.157) for {'bootstrap': True, 'max_depth': 1, 'max_features': 1, 'n_estimators': 10}
# 0.571 (+/-0.123) for {'bootstrap': True, 'max_depth': 1, 'max_features': 1, 'n_estimators': 50}
# 0.608 (+/-0.097) for {'bootstrap': True, 'max_depth': 1, 'max_features': 1, 'n_estimators': 100}
# 0.587 (+/-0.103) for {'bootstrap': True, 'max_depth': 1, 'max_features': 1, 'n_estimators': 200}
# 0.627 (+/-0.084) for {'bootstrap': True, 'max_depth': 1, 'max_features': 1, 'n_estimators': 500}
# 0.420 (+/-0.113) for {'bootstrap': True, 'max_depth': 1, 'max_features': 2, 'n_estimators': 10}
# 0.597 (+/-0.156) for {'bootstrap': True, 'max_depth': 1, 'max_features': 2, 'n_estimators': 50}
# 0.625 (+/-0.096) for {'bootstrap': True, 'max_depth': 1, 'max_features': 2, 'n_estimators': 100}
# 0.629 (+/-0.098) for {'bootstrap': True, 'max_depth': 1, 'max_features': 2, 'n_estimators': 200}
# 0.648 (+/-0.077) for {'bootstrap': True, 'max_depth': 1, 'max_features': 2, 'n_estimators': 500}
# 0.461 (+/-0.225) for {'bootstrap': True, 'max_depth': 1, 'max_features': 3, 'n_estimators': 10}
# 0.620 (+/-0.029) for {'bootstrap': True, 'max_depth': 1, 'max_features': 3, 'n_estimators': 50}
# 0.631 (+/-0.068) for {'bootstrap': True, 'max_depth': 1, 'max_features': 3, 'n_estimators': 100}
# 0.634 (+/-0.083) for {'bootstrap': True, 'max_depth': 1, 'max_features': 3, 'n_estimators': 200}
# 0.653 (+/-0.071) for {'bootstrap': True, 'max_depth': 1, 'max_features': 3, 'n_estimators': 500}
# 0.427 (+/-0.090) for {'bootstrap': True, 'max_depth': 1, 'max_features': 4, 'n_estimators': 10}
# 0.560 (+/-0.074) for {'bootstrap': True, 'max_depth': 1, 'max_features': 4, 'n_estimators': 50}
# 0.599 (+/-0.098) for {'bootstrap': True, 'max_depth': 1, 'max_features': 4, 'n_estimators': 100}
# 0.626 (+/-0.100) for {'bootstrap': True, 'max_depth': 1, 'max_features': 4, 'n_estimators': 200}
# 0.637 (+/-0.063) for {'bootstrap': True, 'max_depth': 1, 'max_features': 4, 'n_estimators': 500}
# 0.416 (+/-0.181) for {'bootstrap': True, 'max_depth': 1, 'max_features': 5, 'n_estimators': 10}
# 0.555 (+/-0.068) for {'bootstrap': True, 'max_depth': 1, 'max_features': 5, 'n_estimators': 50}
# 0.642 (+/-0.080) for {'bootstrap': True, 'max_depth': 1, 'max_features': 5, 'n_estimators': 100}
# 0.599 (+/-0.083) for {'bootstrap': True, 'max_depth': 1, 'max_features': 5, 'n_estimators': 200}
# 0.619 (+/-0.090) for {'bootstrap': True, 'max_depth': 1, 'max_features': 5, 'n_estimators': 500}
# 0.379 (+/-0.161) for {'bootstrap': True, 'max_depth': 1, 'max_features': 6, 'n_estimators': 10}
# 0.543 (+/-0.057) for {'bootstrap': True, 'max_depth': 1, 'max_features': 6, 'n_estimators': 50}
# 0.601 (+/-0.128) for {'bootstrap': True, 'max_depth': 1, 'max_features': 6, 'n_estimators': 100}
# 0.580 (+/-0.101) for {'bootstrap': True, 'max_depth': 1, 'max_features': 6, 'n_estimators': 200}
# 0.609 (+/-0.028) for {'bootstrap': True, 'max_depth': 1, 'max_features': 6, 'n_estimators': 500}
# 0.437 (+/-0.155) for {'bootstrap': True, 'max_depth': 1, 'max_features': 7, 'n_estimators': 10}
# 0.572 (+/-0.132) for {'bootstrap': True, 'max_depth': 1, 'max_features': 7, 'n_estimators': 50}
# 0.576 (+/-0.045) for {'bootstrap': True, 'max_depth': 1, 'max_features': 7, 'n_estimators': 100}
# 0.566 (+/-0.069) for {'bootstrap': True, 'max_depth': 1, 'max_features': 7, 'n_estimators': 200}
# 0.585 (+/-0.117) for {'bootstrap': True, 'max_depth': 1, 'max_features': 7, 'n_estimators': 500}
# 0.421 (+/-0.114) for {'bootstrap': True, 'max_depth': 1, 'max_features': 8, 'n_estimators': 10}
# 0.506 (+/-0.152) for {'bootstrap': True, 'max_depth': 1, 'max_features': 8, 'n_estimators': 50}
# 0.541 (+/-0.056) for {'bootstrap': True, 'max_depth': 1, 'max_features': 8, 'n_estimators': 100}
# 0.571 (+/-0.064) for {'bootstrap': True, 'max_depth': 1, 'max_features': 8, 'n_estimators': 200}
# 0.581 (+/-0.082) for {'bootstrap': True, 'max_depth': 1, 'max_features': 8, 'n_estimators': 500}
# 0.540 (+/-0.243) for {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'n_estimators': 10}
# 0.738 (+/-0.133) for {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'n_estimators': 50}
# 0.780 (+/-0.069) for {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'n_estimators': 100}
# 0.783 (+/-0.074) for {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'n_estimators': 200}
# 0.796 (+/-0.072) for {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'n_estimators': 500}
# 0.581 (+/-0.089) for {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'n_estimators': 10}
# 0.761 (+/-0.090) for {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'n_estimators': 50}
# 0.792 (+/-0.055) for {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'n_estimators': 100}
# 0.809 (+/-0.061) for {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'n_estimators': 200}
# 0.821 (+/-0.046) for {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'n_estimators': 500}
# 0.604 (+/-0.095) for {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'n_estimators': 10}
# 0.784 (+/-0.096) for {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'n_estimators': 50}
# 0.781 (+/-0.039) for {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'n_estimators': 100}
# 0.807 (+/-0.090) for {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'n_estimators': 200}
# 0.818 (+/-0.053) for {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'n_estimators': 500}
# 0.675 (+/-0.140) for {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'n_estimators': 10}
# 0.788 (+/-0.037) for {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'n_estimators': 50}
# 0.808 (+/-0.062) for {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'n_estimators': 100}
# 0.809 (+/-0.096) for {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'n_estimators': 200}
# 0.806 (+/-0.081) for {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'n_estimators': 500}
# 0.637 (+/-0.135) for {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'n_estimators': 10}
# 0.793 (+/-0.082) for {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'n_estimators': 50}
# 0.766 (+/-0.059) for {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'n_estimators': 100}
# 0.805 (+/-0.076) for {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'n_estimators': 200}
# 0.811 (+/-0.088) for {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'n_estimators': 500}
# 0.687 (+/-0.032) for {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'n_estimators': 10}
# 0.792 (+/-0.073) for {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'n_estimators': 50}
# 0.780 (+/-0.096) for {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'n_estimators': 100}
# 0.791 (+/-0.088) for {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'n_estimators': 200}
# 0.801 (+/-0.065) for {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'n_estimators': 500}
# 0.606 (+/-0.164) for {'bootstrap': True, 'max_depth': 2, 'max_features': 7, 'n_estimators': 10}
# 0.754 (+/-0.062) for {'bootstrap': True, 'max_depth': 2, 'max_features': 7, 'n_estimators': 50}
# 0.783 (+/-0.037) for {'bootstrap': True, 'max_depth': 2, 'max_features': 7, 'n_estimators': 100}
# 0.786 (+/-0.060) for {'bootstrap': True, 'max_depth': 2, 'max_features': 7, 'n_estimators': 200}
# 0.795 (+/-0.079) for {'bootstrap': True, 'max_depth': 2, 'max_features': 7, 'n_estimators': 500}
# 0.624 (+/-0.120) for {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'n_estimators': 10}
# 0.751 (+/-0.056) for {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'n_estimators': 50}
# 0.788 (+/-0.052) for {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'n_estimators': 100}
# 0.782 (+/-0.071) for {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'n_estimators': 200}
# 0.787 (+/-0.072) for {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'n_estimators': 500}
# 0.658 (+/-0.048) for {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'n_estimators': 10}
# 0.838 (+/-0.075) for {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'n_estimators': 50}
# 0.844 (+/-0.041) for {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'n_estimators': 100}
# 0.850 (+/-0.044) for {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'n_estimators': 200}
# 0.848 (+/-0.078) for {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'n_estimators': 500}
# 0.696 (+/-0.063) for {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'n_estimators': 10}
# 0.854 (+/-0.033) for {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'n_estimators': 50}
# 0.870 (+/-0.053) for {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'n_estimators': 100}
# 0.865 (+/-0.066) for {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'n_estimators': 200}
# 0.873 (+/-0.052) for {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'n_estimators': 500}
# 0.735 (+/-0.098) for {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'n_estimators': 10}
# 0.862 (+/-0.055) for {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'n_estimators': 50}
# 0.877 (+/-0.035) for {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.875 (+/-0.034) for {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'n_estimators': 200}
# 0.878 (+/-0.037) for {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'n_estimators': 500}
# 0.762 (+/-0.063) for {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'n_estimators': 10}
# 0.851 (+/-0.034) for {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'n_estimators': 50}
# 0.874 (+/-0.072) for {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'n_estimators': 100}
# 0.875 (+/-0.040) for {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'n_estimators': 200}
# 0.885 (+/-0.038) for {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'n_estimators': 500}
# 0.771 (+/-0.066) for {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'n_estimators': 10}
# 0.824 (+/-0.019) for {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'n_estimators': 50}
# 0.874 (+/-0.051) for {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'n_estimators': 100}
# 0.883 (+/-0.048) for {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'n_estimators': 200}
# 0.877 (+/-0.037) for {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'n_estimators': 500}
# 0.740 (+/-0.113) for {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'n_estimators': 10}
# 0.847 (+/-0.080) for {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'n_estimators': 50}
# 0.862 (+/-0.072) for {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'n_estimators': 100}
# 0.875 (+/-0.051) for {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'n_estimators': 200}
# 0.875 (+/-0.045) for {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'n_estimators': 500}
# 0.765 (+/-0.073) for {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'n_estimators': 10}
# 0.860 (+/-0.022) for {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'n_estimators': 50}
# 0.859 (+/-0.049) for {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'n_estimators': 100}
# 0.879 (+/-0.032) for {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'n_estimators': 200}
# 0.877 (+/-0.050) for {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'n_estimators': 500}
# 0.751 (+/-0.063) for {'bootstrap': True, 'max_depth': 3, 'max_features': 8, 'n_estimators': 10}
# 0.843 (+/-0.055) for {'bootstrap': True, 'max_depth': 3, 'max_features': 8, 'n_estimators': 50}
# 0.858 (+/-0.050) for {'bootstrap': True, 'max_depth': 3, 'max_features': 8, 'n_estimators': 100}
# 0.869 (+/-0.046) for {'bootstrap': True, 'max_depth': 3, 'max_features': 8, 'n_estimators': 200}
# 0.862 (+/-0.028) for {'bootstrap': True, 'max_depth': 3, 'max_features': 8, 'n_estimators': 500}
# 0.366 (+/-0.148) for {'bootstrap': False, 'max_depth': 1, 'max_features': 1, 'n_estimators': 10}
# 0.526 (+/-0.079) for {'bootstrap': False, 'max_depth': 1, 'max_features': 1, 'n_estimators': 50}
# 0.582 (+/-0.112) for {'bootstrap': False, 'max_depth': 1, 'max_features': 1, 'n_estimators': 100}
# 0.590 (+/-0.064) for {'bootstrap': False, 'max_depth': 1, 'max_features': 1, 'n_estimators': 200}
# 0.619 (+/-0.071) for {'bootstrap': False, 'max_depth': 1, 'max_features': 1, 'n_estimators': 500}
# 0.330 (+/-0.051) for {'bootstrap': False, 'max_depth': 1, 'max_features': 2, 'n_estimators': 10}
# 0.600 (+/-0.105) for {'bootstrap': False, 'max_depth': 1, 'max_features': 2, 'n_estimators': 50}
# 0.590 (+/-0.039) for {'bootstrap': False, 'max_depth': 1, 'max_features': 2, 'n_estimators': 100}
# 0.641 (+/-0.081) for {'bootstrap': False, 'max_depth': 1, 'max_features': 2, 'n_estimators': 200}
# 0.625 (+/-0.084) for {'bootstrap': False, 'max_depth': 1, 'max_features': 2, 'n_estimators': 500}
# 0.409 (+/-0.117) for {'bootstrap': False, 'max_depth': 1, 'max_features': 3, 'n_estimators': 10}
# 0.582 (+/-0.096) for {'bootstrap': False, 'max_depth': 1, 'max_features': 3, 'n_estimators': 50}
# 0.597 (+/-0.087) for {'bootstrap': False, 'max_depth': 1, 'max_features': 3, 'n_estimators': 100}
# 0.626 (+/-0.051) for {'bootstrap': False, 'max_depth': 1, 'max_features': 3, 'n_estimators': 200}
# 0.625 (+/-0.050) for {'bootstrap': False, 'max_depth': 1, 'max_features': 3, 'n_estimators': 500}
# 0.411 (+/-0.234) for {'bootstrap': False, 'max_depth': 1, 'max_features': 4, 'n_estimators': 10}
# 0.553 (+/-0.044) for {'bootstrap': False, 'max_depth': 1, 'max_features': 4, 'n_estimators': 50}
# 0.592 (+/-0.079) for {'bootstrap': False, 'max_depth': 1, 'max_features': 4, 'n_estimators': 100}
# 0.628 (+/-0.102) for {'bootstrap': False, 'max_depth': 1, 'max_features': 4, 'n_estimators': 200}
# 0.605 (+/-0.098) for {'bootstrap': False, 'max_depth': 1, 'max_features': 4, 'n_estimators': 500}
# 0.411 (+/-0.127) for {'bootstrap': False, 'max_depth': 1, 'max_features': 5, 'n_estimators': 10}
# 0.570 (+/-0.138) for {'bootstrap': False, 'max_depth': 1, 'max_features': 5, 'n_estimators': 50}
# 0.567 (+/-0.060) for {'bootstrap': False, 'max_depth': 1, 'max_features': 5, 'n_estimators': 100}
# 0.573 (+/-0.092) for {'bootstrap': False, 'max_depth': 1, 'max_features': 5, 'n_estimators': 200}
# 0.593 (+/-0.109) for {'bootstrap': False, 'max_depth': 1, 'max_features': 5, 'n_estimators': 500}
# 0.439 (+/-0.102) for {'bootstrap': False, 'max_depth': 1, 'max_features': 6, 'n_estimators': 10}
# 0.529 (+/-0.064) for {'bootstrap': False, 'max_depth': 1, 'max_features': 6, 'n_estimators': 50}
# 0.555 (+/-0.049) for {'bootstrap': False, 'max_depth': 1, 'max_features': 6, 'n_estimators': 100}
# 0.541 (+/-0.083) for {'bootstrap': False, 'max_depth': 1, 'max_features': 6, 'n_estimators': 200}
# 0.549 (+/-0.028) for {'bootstrap': False, 'max_depth': 1, 'max_features': 6, 'n_estimators': 500}
# 0.385 (+/-0.125) for {'bootstrap': False, 'max_depth': 1, 'max_features': 7, 'n_estimators': 10}
# 0.517 (+/-0.102) for {'bootstrap': False, 'max_depth': 1, 'max_features': 7, 'n_estimators': 50}
# 0.546 (+/-0.117) for {'bootstrap': False, 'max_depth': 1, 'max_features': 7, 'n_estimators': 100}
# 0.535 (+/-0.059) for {'bootstrap': False, 'max_depth': 1, 'max_features': 7, 'n_estimators': 200}
# 0.541 (+/-0.056) for {'bootstrap': False, 'max_depth': 1, 'max_features': 7, 'n_estimators': 500}
# 0.419 (+/-0.060) for {'bootstrap': False, 'max_depth': 1, 'max_features': 8, 'n_estimators': 10}
# 0.512 (+/-0.044) for {'bootstrap': False, 'max_depth': 1, 'max_features': 8, 'n_estimators': 50}
# 0.528 (+/-0.074) for {'bootstrap': False, 'max_depth': 1, 'max_features': 8, 'n_estimators': 100}
# 0.520 (+/-0.077) for {'bootstrap': False, 'max_depth': 1, 'max_features': 8, 'n_estimators': 200}
# 0.528 (+/-0.063) for {'bootstrap': False, 'max_depth': 1, 'max_features': 8, 'n_estimators': 500}
# 0.559 (+/-0.117) for {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'n_estimators': 10}
# 0.725 (+/-0.044) for {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'n_estimators': 50}
# 0.746 (+/-0.060) for {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'n_estimators': 100}
# 0.770 (+/-0.082) for {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'n_estimators': 200}
# 0.784 (+/-0.040) for {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'n_estimators': 500}
# 0.628 (+/-0.126) for {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'n_estimators': 10}
# 0.764 (+/-0.102) for {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'n_estimators': 50}
# 0.797 (+/-0.078) for {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'n_estimators': 100}
# 0.790 (+/-0.063) for {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'n_estimators': 200}
# 0.805 (+/-0.075) for {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'n_estimators': 500}
# 0.629 (+/-0.096) for {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'n_estimators': 10}
# 0.785 (+/-0.046) for {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'n_estimators': 50}
# 0.793 (+/-0.092) for {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'n_estimators': 100}
# 0.800 (+/-0.076) for {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'n_estimators': 200}
# 0.807 (+/-0.068) for {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'n_estimators': 500}
# 0.640 (+/-0.103) for {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'n_estimators': 10}
# 0.774 (+/-0.086) for {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'n_estimators': 50}
# 0.789 (+/-0.136) for {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'n_estimators': 100}
# 0.795 (+/-0.104) for {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'n_estimators': 200}
# 0.794 (+/-0.068) for {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'n_estimators': 500}
# 0.649 (+/-0.083) for {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'n_estimators': 10}
# 0.723 (+/-0.094) for {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'n_estimators': 50}
# 0.783 (+/-0.084) for {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'n_estimators': 100}
# 0.786 (+/-0.045) for {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'n_estimators': 200}
# 0.797 (+/-0.051) for {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'n_estimators': 500}
# 0.611 (+/-0.096) for {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'n_estimators': 10}
# 0.783 (+/-0.087) for {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'n_estimators': 50}
# 0.763 (+/-0.077) for {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'n_estimators': 100}
# 0.782 (+/-0.087) for {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'n_estimators': 200}
# 0.790 (+/-0.064) for {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'n_estimators': 500}
# 0.610 (+/-0.111) for {'bootstrap': False, 'max_depth': 2, 'max_features': 7, 'n_estimators': 10}
# 0.714 (+/-0.043) for {'bootstrap': False, 'max_depth': 2, 'max_features': 7, 'n_estimators': 50}
# 0.732 (+/-0.081) for {'bootstrap': False, 'max_depth': 2, 'max_features': 7, 'n_estimators': 100}
# 0.759 (+/-0.066) for {'bootstrap': False, 'max_depth': 2, 'max_features': 7, 'n_estimators': 200}
# 0.768 (+/-0.062) for {'bootstrap': False, 'max_depth': 2, 'max_features': 7, 'n_estimators': 500}
# 0.672 (+/-0.161) for {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'n_estimators': 10}
# 0.729 (+/-0.068) for {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'n_estimators': 50}
# 0.716 (+/-0.107) for {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'n_estimators': 100}
# 0.758 (+/-0.062) for {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'n_estimators': 200}
# 0.763 (+/-0.078) for {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'n_estimators': 500}
# 0.654 (+/-0.106) for {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'n_estimators': 10}
# 0.822 (+/-0.046) for {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'n_estimators': 50}
# 0.831 (+/-0.056) for {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'n_estimators': 100}
# 0.836 (+/-0.062) for {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'n_estimators': 200}
# 0.852 (+/-0.050) for {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'n_estimators': 500}
# 0.714 (+/-0.091) for {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'n_estimators': 10}
# 0.859 (+/-0.033) for {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'n_estimators': 50}
# 0.856 (+/-0.062) for {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'n_estimators': 100}
# 0.868 (+/-0.056) for {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'n_estimators': 200}
# 0.863 (+/-0.072) for {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'n_estimators': 500}
# 0.747 (+/-0.130) for {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'n_estimators': 10}
# 0.859 (+/-0.085) for {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'n_estimators': 50}
# 0.876 (+/-0.031) for {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.876 (+/-0.041) for {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'n_estimators': 200}
# 0.878 (+/-0.051) for {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'n_estimators': 500}
# 0.766 (+/-0.067) for {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'n_estimators': 10}
# 0.863 (+/-0.026) for {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'n_estimators': 50}
# 0.866 (+/-0.045) for {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'n_estimators': 100}
# 0.868 (+/-0.043) for {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'n_estimators': 200}
# 0.879 (+/-0.030) for {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'n_estimators': 500}
# 0.757 (+/-0.094) for {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'n_estimators': 10}
# 0.858 (+/-0.063) for {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'n_estimators': 50}
# 0.865 (+/-0.053) for {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'n_estimators': 100}
# 0.873 (+/-0.052) for {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'n_estimators': 200}
# 0.869 (+/-0.041) for {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'n_estimators': 500}
# 0.797 (+/-0.021) for {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'n_estimators': 10}
# 0.867 (+/-0.029) for {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'n_estimators': 50}
# 0.863 (+/-0.057) for {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'n_estimators': 100}
# 0.859 (+/-0.037) for {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'n_estimators': 200}
# 0.857 (+/-0.070) for {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'n_estimators': 500}
# 0.744 (+/-0.046) for {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'n_estimators': 10}
# 0.838 (+/-0.078) for {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'n_estimators': 50}
# 0.829 (+/-0.068) for {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'n_estimators': 100}
# 0.862 (+/-0.046) for {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'n_estimators': 200}
# 0.856 (+/-0.040) for {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'n_estimators': 500}
# 0.758 (+/-0.049) for {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'n_estimators': 10}
# 0.831 (+/-0.037) for {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'n_estimators': 50}
# 0.837 (+/-0.040) for {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'n_estimators': 100}
# 0.857 (+/-0.033) for {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'n_estimators': 200}
# 0.846 (+/-0.065) for {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'n_estimators': 500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        89
#            1       0.81      0.77      0.79        90
#            2       0.86      0.90      0.88        92
#            3       0.76      0.90      0.82        93
#            4       0.86      0.95      0.90        76
#            5       0.98      0.75      0.85       108
#            6       0.88      0.98      0.93        89
#            7       0.73      0.99      0.84        78
#            8       0.95      0.45      0.61        92
#            9       0.74      0.80      0.77        92
#
#     accuracy                           0.84       899
#    macro avg       0.85      0.85      0.84       899
# weighted avg       0.86      0.84      0.83       899
#
#
# Time Consumed: 238.99443936347961

# %%
start_time = time.time()
warnings.filterwarnings('ignore')

print(__doc__)

# Loading the Digits dataset
digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(digits.images)
X = digits.images.reshape((n_samples, -1))
y = digits.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = {
'learning_rate': [0.1, 0.2, 1], 
'max_depth': [1,2,3],
'n_estimators': [10, 50, 100, 200, 500]}

scores = ['f1']

print('\n' + 'parameters:' + "\n" + str(est.get_params(xgb.XGBClassifier)) + '\n')
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        xgb.XGBClassifier(), tuned_parameters, scoring='%s_macro' % score
    )
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
print("Time Consumed: " + str(time.time()-start_time))
# Out:
# Automatically created module for IPython interactive environment
#
# parameters:
# {'objective': None}
#
# # Tuning hyper-parameters for f1
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200}
#
# Grid scores on development set:
#
# 0.712 (+/-0.113) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 10}
# 0.873 (+/-0.055) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 50}
# 0.906 (+/-0.038) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 100}
# 0.938 (+/-0.034) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 200}
# 0.951 (+/-0.034) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 500}
# 0.853 (+/-0.046) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 10}
# 0.930 (+/-0.014) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# 0.956 (+/-0.029) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 0.958 (+/-0.035) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200}
# 0.955 (+/-0.034) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 500}
# 0.893 (+/-0.023) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 10}
# 0.943 (+/-0.028) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 0.946 (+/-0.027) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 0.954 (+/-0.037) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# 0.957 (+/-0.034) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# 0.793 (+/-0.080) for {'learning_rate': 0.2, 'max_depth': 1, 'n_estimators': 10}
# 0.912 (+/-0.042) for {'learning_rate': 0.2, 'max_depth': 1, 'n_estimators': 50}
# 0.937 (+/-0.040) for {'learning_rate': 0.2, 'max_depth': 1, 'n_estimators': 100}
# 0.946 (+/-0.035) for {'learning_rate': 0.2, 'max_depth': 1, 'n_estimators': 200}
# 0.950 (+/-0.035) for {'learning_rate': 0.2, 'max_depth': 1, 'n_estimators': 500}
# 0.888 (+/-0.042) for {'learning_rate': 0.2, 'max_depth': 2, 'n_estimators': 10}
# 0.956 (+/-0.029) for {'learning_rate': 0.2, 'max_depth': 2, 'n_estimators': 50}
# 0.956 (+/-0.032) for {'learning_rate': 0.2, 'max_depth': 2, 'n_estimators': 100}
# 0.958 (+/-0.031) for {'learning_rate': 0.2, 'max_depth': 2, 'n_estimators': 200}
# 0.956 (+/-0.036) for {'learning_rate': 0.2, 'max_depth': 2, 'n_estimators': 500}
# 0.916 (+/-0.046) for {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 10}
# 0.952 (+/-0.032) for {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 50}
# 0.950 (+/-0.040) for {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100}
# 0.956 (+/-0.036) for {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200}
# 0.951 (+/-0.039) for {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 500}
# 0.880 (+/-0.060) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 10}
# 0.938 (+/-0.038) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 50}
# 0.943 (+/-0.035) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 100}
# 0.942 (+/-0.034) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 200}
# 0.942 (+/-0.031) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 500}
# 0.928 (+/-0.017) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 10}
# 0.943 (+/-0.033) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 50}
# 0.940 (+/-0.032) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 100}
# 0.942 (+/-0.032) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 200}
# 0.940 (+/-0.035) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 500}
# 0.934 (+/-0.028) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 10}
# 0.942 (+/-0.029) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 50}
# 0.941 (+/-0.034) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 100}
# 0.941 (+/-0.034) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 200}
# 0.939 (+/-0.034) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        89
#            1       0.91      0.93      0.92        90
#            2       0.98      0.95      0.96        92
#            3       0.92      0.92      0.92        93
#            4       0.96      0.97      0.97        76
#            5       0.95      0.98      0.97       108
#            6       0.99      0.98      0.98        89
#            7       0.94      0.99      0.96        78
#            8       0.95      0.86      0.90        92
#            9       0.91      0.91      0.91        92
#
#     accuracy                           0.95       899
#    macro avg       0.95      0.95      0.95       899
# weighted avg       0.95      0.95      0.95       899
#
#
# Time Consumed: 128.44877004623413

# %%
start_time = time.time()
warnings.filterwarnings('ignore')

print(__doc__)

# Loading the Digits dataset
digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(digits.images)
X = digits.images.reshape((n_samples, -1))
y = digits.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = {
'bootstrap': [True, False], 
'max_depth': [1,2,3],
'n_estimators': [10, 50, 100, 200, 500],
'max_features': [1,2,3,4,5,6,7,8]}

scores = ['f1']

print('\n' + 'parameters:' + "\n" + str(est.get_params(RandomForestClassifier)) + '\n')
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = RandomizedSearchCV(
        RandomForestClassifier(), tuned_parameters, scoring='%s_macro' % score
    )
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
print("Time Consumed: " + str(time.time()-start_time))
# Out:
# Automatically created module for IPython interactive environment
#
# parameters:
# {'bootstrap': None, 'ccp_alpha': None, 'class_weight': None, 'criterion': None, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': None, 'min_impurity_split': None, 'min_samples_leaf': None, 'min_samples_split': None, 'min_weight_fraction_leaf': None, 'n_estimators': None, 'n_jobs': None, 'oob_score': None, 'random_state': None, 'verbose': None, 'warm_start': None}
#
# # Tuning hyper-parameters for f1
#
# Best parameters set found on development set:
#
# {'n_estimators': 200, 'max_features': 7, 'max_depth': 3, 'bootstrap': True}
#
# Grid scores on development set:
#
# 0.557 (+/-0.091) for {'n_estimators': 50, 'max_features': 6, 'max_depth': 1, 'bootstrap': True}
# 0.406 (+/-0.120) for {'n_estimators': 10, 'max_features': 8, 'max_depth': 1, 'bootstrap': False}
# 0.780 (+/-0.040) for {'n_estimators': 500, 'max_features': 1, 'max_depth': 2, 'bootstrap': False}
# 0.729 (+/-0.096) for {'n_estimators': 50, 'max_features': 3, 'max_depth': 2, 'bootstrap': False}
# 0.757 (+/-0.043) for {'n_estimators': 50, 'max_features': 1, 'max_depth': 2, 'bootstrap': False}
# 0.407 (+/-0.113) for {'n_estimators': 10, 'max_features': 6, 'max_depth': 1, 'bootstrap': True}
# 0.772 (+/-0.078) for {'n_estimators': 10, 'max_features': 8, 'max_depth': 3, 'bootstrap': False}
# 0.574 (+/-0.092) for {'n_estimators': 100, 'max_features': 3, 'max_depth': 1, 'bootstrap': False}
# 0.853 (+/-0.034) for {'n_estimators': 200, 'max_features': 7, 'max_depth': 3, 'bootstrap': True}
# 0.637 (+/-0.054) for {'n_estimators': 10, 'max_features': 4, 'max_depth': 2, 'bootstrap': True}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        89
#            1       0.87      0.68      0.76        90
#            2       0.82      0.91      0.86        92
#            3       0.76      0.89      0.82        93
#            4       0.82      0.95      0.88        76
#            5       0.96      0.76      0.85       108
#            6       0.88      0.98      0.93        89
#            7       0.74      0.97      0.84        78
#            8       0.94      0.50      0.65        92
#            9       0.77      0.82      0.79        92
#
#     accuracy                           0.84       899
#    macro avg       0.85      0.85      0.83       899
# weighted avg       0.85      0.84      0.83       899
#
#
# Time Consumed: 5.554062128067017

# %%
start_time = time.time()
warnings.filterwarnings('ignore')

print(__doc__)

# Loading the Digits dataset
digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(digits.images)
X = digits.images.reshape((n_samples, -1))
y = digits.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = {
'learning_rate': [0.1, 0.2, 1], 
'max_depth': [1,2,3],
'n_estimators': [10, 50, 100, 200, 500]}

scores = ['f1']

print('\n' + 'parameters:' + "\n" + str(est.get_params(xgb.XGBClassifier)) + '\n')
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = RandomizedSearchCV(
        xgb.XGBClassifier(), tuned_parameters, scoring='%s_macro' % score
    )
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
print("Time Consumed: " + str(time.time()-start_time))
# Out:
# Automatically created module for IPython interactive environment
#
# parameters:
# {'objective': None}
#
# # Tuning hyper-parameters for f1
#
# Best parameters set found on development set:
#
# {'n_estimators': 200, 'max_depth': 2, 'learning_rate': 0.1}
#
# Grid scores on development set:
#
# 0.957 (+/-0.034) for {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.1}
# 0.951 (+/-0.034) for {'n_estimators': 500, 'max_depth': 1, 'learning_rate': 0.1}
# 0.939 (+/-0.034) for {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 1}
# 0.956 (+/-0.029) for {'n_estimators': 100, 'max_depth': 2, 'learning_rate': 0.1}
# 0.958 (+/-0.035) for {'n_estimators': 200, 'max_depth': 2, 'learning_rate': 0.1}
# 0.943 (+/-0.035) for {'n_estimators': 100, 'max_depth': 1, 'learning_rate': 1}
# 0.940 (+/-0.032) for {'n_estimators': 100, 'max_depth': 2, 'learning_rate': 1}
# 0.942 (+/-0.034) for {'n_estimators': 200, 'max_depth': 1, 'learning_rate': 1}
# 0.956 (+/-0.029) for {'n_estimators': 50, 'max_depth': 2, 'learning_rate': 0.2}
# 0.930 (+/-0.014) for {'n_estimators': 50, 'max_depth': 2, 'learning_rate': 0.1}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        89
#            1       0.91      0.93      0.92        90
#            2       0.98      0.95      0.96        92
#            3       0.92      0.92      0.92        93
#            4       0.96      0.97      0.97        76
#            5       0.95      0.98      0.97       108
#            6       0.99      0.98      0.98        89
#            7       0.94      0.99      0.96        78
#            8       0.95      0.86      0.90        92
#            9       0.91      0.91      0.91        92
#
#     accuracy                           0.95       899
#    macro avg       0.95      0.95      0.95       899
# weighted avg       0.95      0.95      0.95       899
#
#
# Time Consumed: 36.734776973724365

# %%
'''
grid search essentially brute forces its way through all possible combinations of hyperparameters 
and saves the metrics for the combination with the best performance.

A randomized search provides an alternative to the exhaustive grid search method. 
As the name suggests, it randomly selects combinations of hyperparameters and tests them to find the 
optimal hyperparameter values out of the randomly selected group. 
This method is typically faster than a grid search since it doesn’t test the full range of possibilities.
'''
